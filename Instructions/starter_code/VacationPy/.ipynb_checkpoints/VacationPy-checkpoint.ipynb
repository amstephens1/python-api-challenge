# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
csv_path = "weather_check.csv"
weather_check_df = pd.read_csv(csv_path)
weather_data_df = weather_check_df.drop("Unnamed: 0", 1)
weather_data_df
# Out:
#      Latitude  Longitude           City Country Code  Max Temp  Humidity  \
# 0    -16.4833  -151.7500         faanui           pf     81.63      70.0
# 1     77.4840   -69.3632        qaanaaq           gl     25.36      62.0
# 2     37.4636  -122.4286  half moon bay           us     63.00      82.0
# 3    -23.1203  -134.9692        rikitea           pf     77.05      63.0
# 4     66.0449   -17.3389        husavik           is     35.60      80.0
# ..        ...        ...            ...          ...       ...       ...
# 543   55.0000    25.7833        pabrade           lt     48.99      93.0
# 544   37.2651    35.6572       imamoglu           tr     66.99      94.0
# 545   66.1451   -65.7125    pangnirtung           ca     31.37      74.0
# 546   55.7028    37.3822        marfino           ru     45.00      61.0
# 547   40.1667    21.8167          aiani           gr     51.80      93.0
#
#      Cloudiness  Wind Speed          Date
# 0         100.0        4.14  1.619749e+09
# 1         100.0       10.04  1.619749e+09
# 2           1.0       10.36  1.619749e+09
# 3          77.0       12.84  1.619749e+09
# 4          90.0        5.75  1.619749e+09
# ..          ...         ...           ...
# 543        75.0       11.50  1.619750e+09
# 544         0.0        3.44  1.619750e+09
# 545       100.0        6.11  1.619750e+09
# 546         0.0        6.71  1.619750e+09
# 547         2.0        2.06  1.619750e+09
#
# [548 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations = weather_data_df[["Latitude", "Longitude"]].astype(float)

humidity_percent = weather_data_df["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity_percent, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
temperature_df = weather_data_df[(weather_data_df["Max Temp"]>=70)&(weather_data_df["Max Temp"]<=80)]
wind_speed_df = temperature_df[(temperature_df["Wind Speed"]<10)]
vacation_weather_df = wind_speed_df[(wind_speed_df["Cloudiness"]==0)]
vacation_weather_df
# Out:
#      Latitude  Longitude            City Country Code  Max Temp  Humidity  \
# 136   33.3406    44.4009         baghdad           iq     73.40      38.0
# 148   16.2526   -61.2741  saint-francois           gp     75.20      88.0
# 195   27.2574    33.8129        hurghada           eg     77.00      16.0
# 196  -23.8650    35.3833       inhambane           mz     71.98      77.0
# 299   23.9167  -106.9000         la cruz           mx     70.00      81.0
# 381    4.9333   -52.3333         cayenne           gf     78.01     100.0
# 394    5.1552   -52.6478          kourou           gf     78.01     100.0
# 512   24.6877    46.7219          riyadh           sa     73.40      27.0
# 540   12.4850   -16.5469        oussouye           sn     73.40      83.0
#
#      Cloudiness  Wind Speed          Date
# 136         0.0        6.91  1.619749e+09
# 148         0.0        2.30  1.619750e+09
# 195         0.0        6.91  1.619750e+09
# 196         0.0        5.53  1.619749e+09
# 299         0.0        1.01  1.619750e+09
# 381         0.0        4.29  1.619749e+09
# 394         0.0        3.22  1.619750e+09
# 512         0.0        3.44  1.619749e+09
# 540         0.0        4.61  1.619750e+09

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = vacation_weather_df.reset_index(drop=True)
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#    Latitude  Longitude            City Country Code  Max Temp  Humidity  \
# 0   33.3406    44.4009         baghdad           iq     73.40      38.0
# 1   16.2526   -61.2741  saint-francois           gp     75.20      88.0
# 2   27.2574    33.8129        hurghada           eg     77.00      16.0
# 3  -23.8650    35.3833       inhambane           mz     71.98      77.0
# 4   23.9167  -106.9000         la cruz           mx     70.00      81.0
# 5    4.9333   -52.3333         cayenne           gf     78.01     100.0
# 6    5.1552   -52.6478          kourou           gf     78.01     100.0
# 7   24.6877    46.7219          riyadh           sa     73.40      27.0
# 8   12.4850   -16.5469        oussouye           sn     73.40      83.0
#
#    Cloudiness  Wind Speed          Date Hotel Name
# 0         0.0        6.91  1.619749e+09
# 1         0.0        2.30  1.619750e+09
# 2         0.0        6.91  1.619750e+09
# 3         0.0        5.53  1.619749e+09
# 4         0.0        1.01  1.619750e+09
# 5         0.0        4.29  1.619749e+09
# 6         0.0        3.22  1.619750e+09
# 7         0.0        3.44  1.619749e+09
# 8         0.0        4.61  1.619750e+09

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 100000,
    "type": "hotel",
    "keyword": "hotel",
    "key": g_key,
}

for index, row in hotel_df.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    hotel_name = requests.get(base_url, params=params)
    
    hotel_name = hotel_name.json()
    
    print(json.dumps(hotel_name, indent=4, sort_keys=True))
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
hotel_df
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwI80aKwGvKj4e5U3GTqZzSoRPpSzNiV_ahkutIaw8lcO_bMNbiU0XGXXlY10DJP_RulJoXheiCzN2AoQpBOxtLm4TEo052OlFXuXr03YXtjzKivmErK5IjY6KNSGbLDECgPm8WLxnvYZi-hCs3MlZLlEjUblQPuMs3qEJtu95cSSIbOEuRzTKyoG9PaL6n1v6nPIeOGWnZjIBDnoRAWm-WpTT0IkHsD21-ZwU-8oh66JBMIwJNhK3JIJSOnWNyGdkYf2wz06NUAolsj0g3hCD42rp1K47We4xe22debIqExbBNmMG7njpSwqMUjjn-K1bCZg6vQEB3ZfcPG_eB_VNY-3jRLNMvOgCsfz0xqlQQdlgrj5mxlAzh-wECStHVAv2YkWe585JfpCP2H4FFW--axr2RCQvpDX5_eZT5_H315mW3_KHHXEwwzq9irnFY",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.2912242,
#                     "lng": 44.3904889
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.29235297989273,
#                         "lng": 44.39198562989272
#                     },
#                     "southwest": {
#                         "lat": 33.28965332010728,
#                         "lng": 44.38928597010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Babylon Rotana",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 413,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110588285750081230052\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIVRtoklPh2VamKfbVF3VG8a39bVc_9ynMV16g5SYoP5danTN_3NgaMS86W_PSO1SSod3lNwseihjyvdTDLZB8xJvAukO1UVi9jbnz6G8pCP4jsXVdswRX3xnk-fOJyUi3Pgd-Q7_eD8Ltcw2hN3_tA17qT1yw_zlue6egFQtJVOPhY",
#                     "width": 734
#                 }
#             ],
#             "place_id": "ChIJbQTLVoV_VxURIJeFmZoVXPI",
#             "plus_code": {
#                 "compound_code": "79RR+F5 Baghdad, Iraq",
#                 "global_code": "8H5679RR+F5"
#             },
#             "rating": 4.4,
#             "reference": "ChIJbQTLVoV_VxURIJeFmZoVXPI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4066,
#             "vicinity": "Karada Street, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3186679,
#                     "lng": 44.4150578
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.31993267989273,
#                         "lng": 44.41626747989272
#                     },
#                     "southwest": {
#                         "lat": 33.31723302010728,
#                         "lng": 44.41356782010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Baghdad Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 640,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108347342884704873549\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLh9P1MagHAhnoAgZjEwKkMyZW__29dhOu6eJ4t73Gki_MKPh5bDip7OAVDRjhCzltz6fkr130k4hqkslVhGjexlzESiL3BX7bHIZOhZZu5kNDKDKKS6-mZ1w5qfNvUwWHUQjhiLh4OyP5iD9rfjDhc_bHVwR4LyrYpO9JBMHp6HV4B",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJBRbRs_OBVxURY2n0GSImCOo",
#             "plus_code": {
#                 "compound_code": "8C98+F2 Baghdad, Iraq",
#                 "global_code": "8H568C98+F2"
#             },
#             "rating": 4,
#             "reference": "ChIJBRbRs_OBVxURY2n0GSImCOo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1202,
#             "vicinity": "Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.282766,
#                     "lng": 44.394008
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.28408992989271,
#                         "lng": 44.39524887989272
#                     },
#                     "southwest": {
#                         "lat": 33.28139027010727,
#                         "lng": 44.39254922010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Coral Baghdad Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 375,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104399176913316572083\">\u0627\u0644\u0634\u064a\u0639\u064a \u0627\u0644\u0633\u0627\u0639\u062f\u064a \u062f\u0627\u0639\u0633 \u0631\u0623\u0633 \u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0629</a>"
#                     ],
#                     "photo_reference": "ATtYBwJUKsjkmLrUa-dv6lTV8-KLp4VXstRuGV8UzPlkH5cE7t5bAgPX1S7FOu2Dri1CkYap2tAgEEmE1SU3BOiSzXhu7bDhtowiAQACMsFfuS8zlccD3Sedy9re1iq-C17nUbOb9nzqZ3QIcUTv0FwJEdPCW-94zqXTEdnReb5P6lKGrqI4",
#                     "width": 500
#                 }
#             ],
#             "place_id": "ChIJSQw0PyGCVxURb6dLE1fyIrs",
#             "plus_code": {
#                 "compound_code": "79MV+4J Baghdad, Iraq",
#                 "global_code": "8H5679MV+4J"
#             },
#             "rating": 4.1,
#             "reference": "ChIJSQw0PyGCVxURb6dLE1fyIrs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1030,
#             "vicinity": "University Street, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3235429,
#                     "lng": 44.4195681
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.32482712989272,
#                         "lng": 44.42095117989272
#                     },
#                     "southwest": {
#                         "lat": 33.32212747010728,
#                         "lng": 44.41825152010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Shanashel Palace Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115025130339132690024\">Aqeel Salih</a>"
#                     ],
#                     "photo_reference": "ATtYBwLEmn43C2sMAg1D5HkQ3gPgifV6uyKSA5ZnVnY8PlrJx0jYBXGbhJr7BeQIufIxZMn0ZwXk5EiAY7MXrHSphXUAMYrts6lIx_Yrnl7QO1K1e53Tk6e5qfusCCPKSyMv6Y-jdoDYzDKeLQTxGLMmAZR1KczTZSp99YGr7yudSLpCItU3",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJOUpIbCCCVxURRjdv_WaKIfY",
#             "plus_code": {
#                 "compound_code": "8CF9+CR Baghdad, Iraq",
#                 "global_code": "8H568CF9+CR"
#             },
#             "rating": 4,
#             "reference": "ChIJOUpIbCCCVxURRjdv_WaKIfY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 255,
#             "vicinity": "Baghdad, Alnidhal Street"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.2937009,
#                     "lng": 44.428013
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.29504917989272,
#                         "lng": 44.42935877989272
#                     },
#                     "southwest": {
#                         "lat": 33.29234952010727,
#                         "lng": 44.42665912010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "BILITOM HOTEL",
#             "photos": [
#                 {
#                     "height": 2252,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104549978723953261352\">omar azeez</a>"
#                     ],
#                     "photo_reference": "ATtYBwKINCKYQj7Zb80SVxuyucaPqAE-jSIGb52MrlnjcNQxeV1z3SNR2Zcoy1ytEWMphWWqMeACNkDa_2L1FGHghlC0SrBQYttZZlevbI0uuklWrT3liHTqNVoMMAVmmiWmQhu2ooLYPHvxqb9AQVmpDzW-RlBkjefRrF4hj3P5di-0_68U",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJCyJ6aRiBVxUR4d8eYwJrQBg",
#             "plus_code": {
#                 "compound_code": "7CVH+F6 Baghdad, Iraq",
#                 "global_code": "8H567CVH+F6"
#             },
#             "rating": 4.5,
#             "reference": "ChIJCyJ6aRiBVxUR4d8eYwJrQBg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "\u0634\u0627\u0631\u0639 \u0627\u0644\u0639\u0631\u0635\u0627\u062a\u060c \u0628\u063a\u062f\u0627\u062f\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.287646,
#                     "lng": 44.3880472
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.28888372989272,
#                         "lng": 44.38946802989272
#                     },
#                     "southwest": {
#                         "lat": 33.28618407010727,
#                         "lng": 44.38676837010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Coral Palace Hotel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109068623642198162343\">Bashar Ali</a>"
#                     ],
#                     "photo_reference": "ATtYBwINgDPTnwGUHdnQAG_l51b3R-qmUvd13DzQmMF9iA_jyoqJVhPK0NR78L6x6D1iNQdIVr9NM4vloPTV7QJd7J_VnFk28YubGDI5E9sDycK6wslrL4U9dLtwXbnj4T9waRDmhg7JGraY1xRaT3nfwb_n7LEP02S94TICRlyy522_T0wa",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJUXcU5uZ_VxURUuUZi5YZr1Y",
#             "plus_code": {
#                 "compound_code": "79QQ+36 Baghdad, Iraq",
#                 "global_code": "8H5679QQ+36"
#             },
#             "rating": 4.4,
#             "reference": "ChIJUXcU5uZ_VxURUuUZi5YZr1Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 44,
#             "vicinity": "Unnamed Road"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.315771,
#                     "lng": 44.417444
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.31703562989271,
#                         "lng": 44.41863497989272
#                     },
#                     "southwest": {
#                         "lat": 33.31433597010727,
#                         "lng": 44.41593532010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Andalus Hotel suites",
#             "photos": [
#                 {
#                     "height": 3072,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107067728422402254225\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIqMMJKuVMRyzmIPhS9EL2-EVJXT_FffrZ1L5I5-IXWnRm78K-Jcn0cZ5Kj_nwuEIfMgmPEyPSfMvUeCcdHhEkZ3FlI0VivWsDOwSHI9eoW8-EEUyDoYFhVZqu8-JnPCcvyq1ouSxdfC49URHY_jYdtkSnaHHU84ihtOQN_0tgvbnAZ",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJ51Mpz_KBVxURrwnP2YK2bNk",
#             "plus_code": {
#                 "compound_code": "8C88+8X Baghdad, Iraq",
#                 "global_code": "8H568C88+8X"
#             },
#             "rating": 4,
#             "reference": "ChIJ51Mpz_KBVxURrwnP2YK2bNk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 187,
#             "vicinity": "Abu Nawas, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3114911,
#                     "lng": 44.4254395
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.31281152989273,
#                         "lng": 44.42674707989271
#                     },
#                     "southwest": {
#                         "lat": 33.31011187010728,
#                         "lng": 44.42404742010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Rukn Kahramana Baghdad",
#             "photos": [
#                 {
#                     "height": 540,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110517461831196287024\">\u062d\u0645\u062f\u0645\u062f</a>"
#                     ],
#                     "photo_reference": "ATtYBwJUP1IowrQj36xIcOv9z2FrxyCWao6xEpRQcW36xnFp_BGhim8vBg9hLMpwo3zhih1gs5Vg6gALFiCGJahS9eRkCkPgcKLfA3PA6ZgBtLC8gDtxaXtmgUjG3CXmfrc-deOtn9Nf7kCxT-olq3uD2SI0haO6Ap5HP_jGgvdGcnSCylu8",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJ-QN404-BVxURqyPX80Nj-5E",
#             "plus_code": {
#                 "compound_code": "8C6G+H5 Baghdad, Iraq",
#                 "global_code": "8H568C6G+H5"
#             },
#             "rating": 3.7,
#             "reference": "ChIJ-QN404-BVxURqyPX80Nj-5E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 367,
#             "vicinity": "Kahramana Courtyard, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.2850332,
#                     "lng": 44.3975698
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.28618327989273,
#                         "lng": 44.39903127989272
#                     },
#                     "southwest": {
#                         "lat": 33.28348362010728,
#                         "lng": 44.39633162010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Taj Hotel - \u0641\u0646\u062f\u0642 \u0627\u0644\u062a\u0627\u062c",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111698106703707284831\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ8FW6py8Qf_9HLR4TsPlWD0yJV6euEOQoA-jI0gPnYQDQSyX9t_argo8o3V2XttrgriKTpc5-pClomp6bRx17pAooDoHoZyHJwSqDQKKlMDaYVtI_gE_LeCHiamXjgk4_HAWbBeNJ8RQBLbF0c8TP7ObJbu4a3fgtHLENwGxYc8Qcd",
#                     "width": 6720
#                 }
#             ],
#             "place_id": "ChIJnasKtnt_VxURjzSowMAEfJE",
#             "plus_code": {
#                 "compound_code": "79PX+22 Baghdad, Iraq",
#                 "global_code": "8H5679PX+22"
#             },
#             "rating": 4.5,
#             "reference": "ChIJnasKtnt_VxURjzSowMAEfJE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 159,
#             "vicinity": "Jamia St, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3154148,
#                     "lng": 44.4190639
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.31652302989272,
#                         "lng": 44.42050047989272
#                     },
#                     "southwest": {
#                         "lat": 33.31382337010728,
#                         "lng": 44.41780082010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "International Palestine Hotel",
#             "photos": [
#                 {
#                     "height": 6936,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118182183665252409229\">Hassanen Wijdan</a>"
#                     ],
#                     "photo_reference": "ATtYBwJhXkX5LeH5gp7nfluQfzjcT7itZe1VkwM5YjX3FOcFrWlGt9go39OFKLOkklv1AD0qHBGs5Jj7uJz9tZ7GZfU1ZkWrolSdLWVu-OT7VTzyDI5CuyXwUVXBJQ7DrugW1b-lKwZDj3cGxOX0gsgf9WnFe6hs_1KtMQT-FUUblB3V29LY",
#                     "width": 9248
#                 }
#             ],
#             "place_id": "ChIJ1T5VNo2BVxUR4DaQ_howEg8",
#             "plus_code": {
#                 "compound_code": "8C89+5J Baghdad, Iraq",
#                 "global_code": "8H568C89+5J"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ1T5VNo2BVxUR4DaQ_howEg8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 997,
#             "vicinity": "Al-Sa'doon Street, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3138862,
#                     "lng": 44.4190463
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.31511587989272,
#                         "lng": 44.42013582989271
#                     },
#                     "southwest": {
#                         "lat": 33.31241622010728,
#                         "lng": 44.41743617010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Crystal Grand Hotel Ishtar",
#             "photos": [
#                 {
#                     "height": 6936,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118182183665252409229\">Hassanen Wijdan</a>"
#                     ],
#                     "photo_reference": "ATtYBwKBAiJ5gYNKFuoRFfZAMyvaP7jNa_yrRc7TC97hIk3q0R9sW91rmnoLxH5qbEz2d01F6X7G0zCiMUu9fxri7F4C8_Gw8dC7nXE6NlfxzODF1gnOwV0YMz4811PZjeyujc31A9xuWy8PYIL8PwDm3REfVZVTxxI7oqrPCXtN1C7KlC2T",
#                     "width": 9248
#                 }
#             ],
#             "place_id": "ChIJx8cnp5KBVxUR29O1hAQdv9s",
#             "plus_code": {
#                 "compound_code": "8C79+HJ Baghdad, Iraq",
#                 "global_code": "8H568C79+HJ"
#             },
#             "rating": 3.8,
#             "reference": "ChIJx8cnp5KBVxUR29O1hAQdv9s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 675,
#             "vicinity": "Abu Nuw'as Street, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3278837,
#                     "lng": 44.3961653
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.32891172989272,
#                         "lng": 44.39708567989271
#                     },
#                     "southwest": {
#                         "lat": 33.32621207010727,
#                         "lng": 44.39438602010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Al-Mansour Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101202976795185048691\">Husam Namir</a>"
#                     ],
#                     "photo_reference": "ATtYBwKBrf-V04pIMgBEC8BQTljWlwsNHFcIahEh90T-ucowoay90M9vm8d-kaJvDq24KOYam4e5bVsT5wZqaxLpO0mS4R8OueBX9Z8fwiIOTNZf_xb5u4FLBARzqoo5OHikJDYpf_FdFgzyPoksmPcGP4--BiwL2fx5Z2p-sODoXMejUNMj",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJrfHOj1Z_VxUR3K9mePdkR7o",
#             "plus_code": {
#                 "compound_code": "89HW+5F Baghdad, Iraq",
#                 "global_code": "8H5689HW+5F"
#             },
#             "rating": 3.9,
#             "reference": "ChIJrfHOj1Z_VxUR3K9mePdkR7o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1842,
#             "vicinity": "Sinak Bridge, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3006088,
#                     "lng": 44.4373289
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.30183007989272,
#                         "lng": 44.43875117989273
#                     },
#                     "southwest": {
#                         "lat": 33.29913042010728,
#                         "lng": 44.43605152010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Sindbad Palace Hotel",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109158571414710951357\">mohammed ahmmed</a>"
#                     ],
#                     "photo_reference": "ATtYBwI6SSsuHBuKzIzWqFk_a-BMXTupt4BQA-OddiwqRrlLP7HFlCrIhZAZCkHGj7oRdP2fRfyElhvu9kSoJKtNHF5i4ZWaiplmShB-NKv9wtdL6IQL8AfOz5UI7I7P4J6b5j7wLfgKXH8U52O9QMl-BsEL3VRzM4cnxxxn9PEHF5N9GYVN",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJHUVL8XWBVxURqdruzc6hr6c",
#             "plus_code": {
#                 "compound_code": "8C2P+6W Baghdad, Iraq",
#                 "global_code": "8H568C2P+6W"
#             },
#             "rating": 3.8,
#             "reference": "ChIJHUVL8XWBVxURqdruzc6hr6c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 192,
#             "vicinity": "5 Karada Kharidge, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3799692,
#                     "lng": 44.3422499
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.38131902989272,
#                         "lng": 44.34359972989272
#                     },
#                     "southwest": {
#                         "lat": 33.37861937010727,
#                         "lng": 44.34090007010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Teeba Hotel",
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106574170081864027653\">Israa Obaidy</a>"
#                     ],
#                     "photo_reference": "ATtYBwLpjfV6nc4lN_oYl2lQLuwqJRN_fHxLjjZltgxYultsVqHv30kLhIZS-QhycTN4qkCyJAiYF1GYsEvOqiM4jBQZAZOzvqYVzb4LZZR9Zm-qHnVd3ZSBncBPT_TJcyhIVnGpfexQuBskZu_33Ls-HzRBh1BX7OFeMOHw7N_OqaBC_bie",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJ5_F8Vmt5VxUR3wkOEjJqHsQ",
#             "plus_code": {
#                 "compound_code": "98HR+XV Baghdad, Iraq",
#                 "global_code": "8H5698HR+XV"
#             },
#             "rating": 3.3,
#             "reference": "ChIJ5_F8Vmt5VxUR3wkOEjJqHsQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 46,
#             "vicinity": "Zahra Street, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.2594885,
#                     "lng": 44.2335876
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.26112657989272,
#                         "lng": 44.23508432989272
#                     },
#                     "southwest": {
#                         "lat": 33.25842692010728,
#                         "lng": 44.23238467010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Baghdad International Airport Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1280,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108096530808984956879\">Abir Burhan</a>"
#                     ],
#                     "photo_reference": "ATtYBwIbh868endGc7WfHF1o8TgyjJ0ZiHEQcIM9IjRQOEQUijAqKlnA9xeSTewYI1jivXVR_JzZMnQci7Uo-PdpfV9Gi572Ybnrxmhc0oM1p9js6iSdX2yuNNb387p_G5R0W10sM3dz02DwbWVsHaAInVX4LLleA3WVUn1jUhKQ6bH4z8Ys",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJBZm7fx7aWRURnV4-YMoBeLY",
#             "plus_code": {
#                 "compound_code": "765M+QC Baghdad, Iraq",
#                 "global_code": "8H56765M+QC"
#             },
#             "rating": 3.7,
#             "reference": "ChIJBZm7fx7aWRURnV4-YMoBeLY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 103,
#             "vicinity": "Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3144248,
#                     "lng": 44.4199869
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.31586537989272,
#                         "lng": 44.42133907989272
#                     },
#                     "southwest": {
#                         "lat": 33.31316572010728,
#                         "lng": 44.41863942010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ishtar Sheraton Tower",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104668412889902231600\">Jun Won Song</a>"
#                     ],
#                     "photo_reference": "ATtYBwJJO-qjMrzhtg0RZZ9tz62qCQCsTNWxKqg6zvoNz4q311c5ca_jkyavfqxkLQPJjcgray0nzCTEttwZ2Ae8TsRy06XXLFoL-k9ovZONAAu4CrBOIWognzL1PXz5aeo7c4N6O70i75y-6vVP9wpqf_kp3jL6Qe8WZG7sVkywd6LjMLR0",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJSZeHoJKBVxURFMRiUy47N4g",
#             "plus_code": {
#                 "compound_code": "8C79+QX Baghdad, Iraq",
#                 "global_code": "8H568C79+QX"
#             },
#             "rating": 3.8,
#             "reference": "ChIJSZeHoJKBVxURFMRiUy47N4g",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 800,
#             "vicinity": "Al-Sa'doon St, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.2429402,
#                     "lng": 44.2461719
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.24432197989272,
#                         "lng": 44.24758837989272
#                     },
#                     "southwest": {
#                         "lat": 33.24162232010728,
#                         "lng": 44.24488872010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Al-Burhan Centre",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2640,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117752700158617559566\">Al-Burhan Group</a>"
#                     ],
#                     "photo_reference": "ATtYBwJPrNuStTpcecUWxN7DstMw0Wqozx6jKv3WjoluHNSMGw3iZ64IJ8Z9HcHSAJ14Dqz4a3zK1vo0obNpwSGQYviFy7fvvKsPCPrBFst_8FJDd_gi9WWX6k-4DlyeQZswQmVXK2bZpwsJLcDcuNVj__17dMqQjs4FXU_x-i6uIHE_cwQe",
#                     "width": 5121
#                 }
#             ],
#             "place_id": "ChIJcc_uLEbbWRUR3oAz8OJXii4",
#             "plus_code": {
#                 "compound_code": "66VW+5F Baghdad, Iraq",
#                 "global_code": "8H5666VW+5F"
#             },
#             "rating": 4.5,
#             "reference": "ChIJcc_uLEbbWRUR3oAz8OJXii4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 69,
#             "vicinity": "International Airport\u060c Al-Burhan Street\u060c Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3162091,
#                     "lng": 44.3893153
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.31729952989273,
#                         "lng": 44.39094107989272
#                     },
#                     "southwest": {
#                         "lat": 33.31459987010728,
#                         "lng": 44.38824142010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Royal Tulip Al Rasheed Hotel",
#             "photos": [
#                 {
#                     "height": 719,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105909092333806480521\">ahmed alquraishy</a>"
#                     ],
#                     "photo_reference": "ATtYBwKfIixyOFlGrtkO3hG2IrTvqUDR9rVMKLtRWZk0NV3w9PWXYPGawUgxyQ9Cu3i4T9w7i5oJlATcIsy3R2XIdzoXaaQvm8dnPo5apQLpxumra2Vj90HsEBZUj2WoVEL3N6dEOKE-5mZtR9fV0tg-JFPLiFD1NqFFpr4A9Gt8Kw-oa7sV",
#                     "width": 1279
#                 }
#             ],
#             "place_id": "ChIJdb4fh2h_VxURmeBRiZyaBCg",
#             "plus_code": {
#                 "compound_code": "898Q+FP Baghdad, Iraq",
#                 "global_code": "8H56898Q+FP"
#             },
#             "rating": 4.2,
#             "reference": "ChIJdb4fh2h_VxURmeBRiZyaBCg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 890,
#             "vicinity": "Baghdad Tower, Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3004053,
#                     "lng": 44.4203156
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.30172292989273,
#                         "lng": 44.42161127989272
#                     },
#                     "southwest": {
#                         "lat": 33.29902327010728,
#                         "lng": 44.41891162010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Inter Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118254765271515881603\">\u0646\u0627\u0635\u0631 \u0627\u0644\u062d\u062c\u0631\u064a</a>"
#                     ],
#                     "photo_reference": "ATtYBwITfV_o9ENgjiapHs1fhfougrfMfhNzVvTkJ9wZqogPE18jtecUpmg93N-OdnbwSJiZR3d_2WzJuIM-P8kAMUVso7WW19O2Hc2WxcuguRSXALef4s21ln48xft0UiJstoUU5jl6mMSx16SZhQwyFGAkTgZAkWvGsbOZKJ1tT9dAoDiU",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJhfe_KL-BVxURmMdg6iGIxW0",
#             "plus_code": {
#                 "compound_code": "8C2C+54 Baghdad, Iraq",
#                 "global_code": "8H568C2C+54"
#             },
#             "rating": 3.5,
#             "reference": "ChIJhfe_KL-BVxURmMdg6iGIxW0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 174,
#             "vicinity": "Baghdad"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.2914709,
#                     "lng": 44.42222170000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.29288017989273,
#                         "lng": 44.42353867989273
#                     },
#                     "southwest": {
#                         "lat": 33.29018052010728,
#                         "lng": 44.42083902010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Bloom Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4624,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113834430660598564855\">ahmed yalova</a>"
#                     ],
#                     "photo_reference": "ATtYBwJYugtugMMD0wskPj6XMjvHdQb3YooMQOYXnj9EO6rgdd2hgWojoPd-QAVuAIDzuiipwhJEI2LyZFV6D4b1x2lZEpbn90dm_8Bbt5XUBMmFMLzYzm0e9yEgMa3--tIQ9dLqCVD-GC1MbhZ8OZfGqLeiF0qhoSYSy58VusS-oP3Al5Zv",
#                     "width": 3468
#                 }
#             ],
#             "place_id": "ChIJVVWV4KSBVxUR5n2sVj3pk3w",
#             "plus_code": {
#                 "compound_code": "7CRC+HV Baghdad, Iraq",
#                 "global_code": "8H567CRC+HV"
#             },
#             "rating": 3.8,
#             "reference": "ChIJVVWV4KSBVxUR5n2sVj3pk3w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 511,
#             "vicinity": "Arasat Al-Hindiyah, Baghdad"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwJIUif29UDGtIcGgp64ZTLk5ogMo8KxIbqWTI0Z_A4a_KozlW6x8cF5tcs5aZ34cCF4y1XInw5Q_PqB5UU3Sbm8z0g-QomclXjyCB8bScIAgcWFEJBTU_knG_V21ghfFfy26P-4uDyE9dRzP57GWF8xZJsrDWntwtnpnkQyn4qs855iloAREW-tGhnRC0A8I0JRrMIjgKOMowbuzHuDz3K9kCE3vsOVJAnFd3V3uVroNrNu4iMc00qjWbxBIDPhosd7ubRvx0UGdX73K6flk84r5QugYU6LAGG0JQJrU-SNNK08-LyGjT34qhQEi9-T0i0pYu3mi7sVslY3X1CHXoV_eTHbPj2GPvRuLWUhEK2sa5vTqLvi03p-eCG5vyBa3xXhwhb5dveA_pHAPyVUV7PEQMoRWeF8A1MLCkAHlQNFxTunrONOFnXewgNQAZw",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 16.207,
#                     "lng": -61.50670599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 16.20828217989273,
#                         "lng": -61.50552372010727
#                     },
#                     "southwest": {
#                         "lat": 16.20558252010728,
#                         "lng": -61.50822337989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "LA CREOLE BEACH HOTEL & SPA",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2992,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101880618551063838657\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKNOhW3Nai2uxu_TPythcp2iY9aDsJ_L3wekm_WzwtQDzedEj57DsPFzDga6zu2ZJqxfNnr_rCaA_vbfoiMJ9OFLBlPH7xSI_fIqmu86F2Ci2i3nopnX026lWcT8Tx9bjfOohYFBEut1ay5iAB-raneOjpQnygA7rQ4S4xYBZ9e_15m",
#                     "width": 3992
#                 }
#             ],
#             "place_id": "ChIJJQQszT9PE4wRbqF2-xDvEKI",
#             "plus_code": {
#                 "compound_code": "6F4V+Q8 Le Gosier, Guadeloupe",
#                 "global_code": "778W6F4V+Q8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJJQQszT9PE4wRbqF2-xDvEKI",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1457,
#             "vicinity": "Pointe de la Verdure, Gosier"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 16.2091861,
#                     "lng": -61.50812740000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 16.21061997989272,
#                         "lng": -61.50657882010728
#                     },
#                     "southwest": {
#                         "lat": 16.20792032010728,
#                         "lng": -61.50927847989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f4tel Canella Beach",
#             "photos": [
#                 {
#                     "height": 2830,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105347503744308241761\">Canella Beach Hotel Residence Gosier</a>"
#                     ],
#                     "photo_reference": "ATtYBwI8KpOF-tHi58jPPJMscbLK5b2IqDOGea5sh2ZtfQXavO_R0CzBMF_R772jFfzPJv7FY8Ql9AIxVr3k6UOMhpBqYTFdxNKaCpoeZ3qz-DOgzJ8KgY9qyvkVJtDTDJ8MBrU5zVacwUpfutj1e5n6TU6Heaa1Xxtlo-RHNCmGluEBL8Yt",
#                     "width": 4239
#                 }
#             ],
#             "place_id": "ChIJFzBnD2RPE4wRGBQ-VeMTrp8",
#             "plus_code": {
#                 "compound_code": "6F5R+MP Le Gosier, Guadeloupe",
#                 "global_code": "778W6F5R+MP"
#             },
#             "rating": 4,
#             "reference": "ChIJFzBnD2RPE4wRGBQ-VeMTrp8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 462,
#             "vicinity": "Pointe de la Verdure, Le Gosier"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 16.245453,
#                     "lng": -61.29411
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 16.24689417989272,
#                         "lng": -61.29267227010727
#                     },
#                     "southwest": {
#                         "lat": 16.24419452010727,
#                         "lng": -61.29537192989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Le Manganao Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 450,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102976177505179757265\">Les R\u00e9sidences du Manganao</a>"
#                     ],
#                     "photo_reference": "ATtYBwKpCt4rr09HetQtMlwPvc8cgmT_XjBym674gn1vNeiv_co5-3fvLe2P9uYxKapEssV96GdARNRnqt8UL88750a6dvC-hMd0kB6i66GaXTNnlGrH3fLosoTF3AjItRjNetnd8yVDm5oaBSvmYQ65SFpvfpwyPD_uE2p4SpCTDv0UaHYD",
#                     "width": 600
#                 }
#             ],
#             "place_id": "ChIJxz7E_OK0bIwR_km9BybFqsE",
#             "plus_code": {
#                 "compound_code": "6PW4+59 Saint-Fran\u00e7ois, Guadeloupe",
#                 "global_code": "778W6PW4+59"
#             },
#             "rating": 4.1,
#             "reference": "ChIJxz7E_OK0bIwR_km9BybFqsE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 349,
#             "vicinity": "lieu-dit Bellevue, N4, Saint Fran\u00e7ois"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 16.207236,
#                     "lng": -61.507515
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 16.20887177989272,
#                         "lng": -61.50600942010728
#                     },
#                     "southwest": {
#                         "lat": 16.20617212010728,
#                         "lng": -61.50870907989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "MAHOGANY HOTEL RESIDENCE & SPA",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102137293832381115197\">MAHOGANY HOTEL RESIDENCE &amp; SPA</a>"
#                     ],
#                     "photo_reference": "ATtYBwL-5qE3IohYM49d8TbPR531yobvPsZgjjPs5xzuvEvyRjuvl7Ox7kTRQlP0RP8VGsLK9cZgA0zsrIWPqveusASQs6mTz8W9n1Q1LB1XfNiqEJeQ3gF0o_ecYAKytuwf8A0OGC0BrMr2mP7r8LvN5hen3lOiE9nhtKOAJwGOd8vz3Wwv",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJJ6w4fmRPE4wRAkMpZ4gHHFo",
#             "plus_code": {
#                 "compound_code": "6F4R+VX Le Gosier, Guadeloupe",
#                 "global_code": "778W6F4R+VX"
#             },
#             "rating": 3.9,
#             "reference": "ChIJJ6w4fmRPE4wRAkMpZ4gHHFo",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 37,
#             "vicinity": "Pointe de la Verdure, Gosier"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 16.2063036,
#                     "lng": -61.4990346
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 16.20765117989272,
#                         "lng": -61.49767847010727
#                     },
#                     "southwest": {
#                         "lat": 16.20495152010728,
#                         "lng": -61.50037812989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Auberge de La Vieille Tour",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109754222037166638797\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJw8CDutF3QsZArMCsGcxseexCNERsHdIg40nYTVY8Ljb70pF6CHXCiqcNEDjAQRb0NUxKclTL1oM3TZ-hTcGXtgdGYpCrfmczp3toxzPtUZr3uEubJ9pDQ-w0tSqgYCFZnSo44hL6-Nxdc-rzRVa-QGeYRzBhsH6t0uC3LKLtQDXc4",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJAQAAAABdE4wRXM-exc2782E",
#             "plus_code": {
# ...
#                         "lat": 12.51329022010728,
#                         "lng": -16.60043627989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Kabekel",
#             "photos": [
#                 {
#                     "height": 780,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108833876444820924661\">donat lambal</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ63ThOP-jo1t3svQhXPAsOj54AUkSEGzExVrNJNbTJJvW0ThpWggwIhgXeTPNArL1iYDvwIclJxwugtit6_AJYTT93TVZPsyt8TmaQjaYMfgzBnUEHfkb_dYVctp3aq94fuAlJEuX7Ohi4UDC-X0Sr5yE6nISJ79yxH92B1VxM17nN",
#                     "width": 1040
#                 }
#             ],
#             "place_id": "ChIJcdo3sKZj3Q4Rm_76NIgd6xs",
#             "plus_code": {
#                 "compound_code": "GC72+V9 Oussouye, Senegal",
#                 "global_code": "7C45GC72+V9"
#             },
#             "rating": 2.5,
#             "reference": "ChIJcdo3sKZj3Q4Rm_76NIgd6xs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "88 Route de Saint-Romain 2\u00e8 \u00e9tage porte droite, Oussouye"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 12.4338568,
#                     "lng": -16.7814617
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.43520662989272,
#                         "lng": -16.78011187010728
#                     },
#                     "southwest": {
#                         "lat": 12.43250697010728,
#                         "lng": -16.78281152989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Le Kibalaou",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2270,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110330478954466922818\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwK8Q9KfBbO78-LuVk9yqYxvENi6TXjcQLgvl8HhlxI_14ugyvLFtJ_wce0EPpDy54m0MKMtN36Wg-Sac8zTPk_PSnsU7BWfinCgJKSCFz8xrIvKhYTf1j0xya6gWx6ZlVSXlK1-2wbzf6VVirTyLVWjGBObrYdYq3fM-vVv-ISJn9Db",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJo6QFachx3Q4RC5gt479b59Q",
#             "plus_code": {
#                 "compound_code": "C6M9+GC Diemb\u00e9reng, Senegal",
#                 "global_code": "7C45C6M9+GC"
#             },
#             "rating": 4.7,
#             "reference": "ChIJo6QFachx3Q4RC5gt479b59Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 11,
#             "vicinity": "Plage boukote, Di\u00e9b\u00e9ring"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 12.3579918,
#                     "lng": -16.7173612
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.35937692989272,
#                         "lng": -16.71594632010727
#                     },
#                     "southwest": {
#                         "lat": 12.35667727010728,
#                         "lng": -16.71864597989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fromager",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107236526285432955757\">guy c</a>"
#                     ],
#                     "photo_reference": "ATtYBwIh7xxeNTcwOAdBbf30imeBLcONb5uOuhLSp3buERkfMvKWCjGTPURnAArJzrHIMcHkOwSbZnWRt6JzIY58_ZD4ocQUbPZQcaJuibukiiRViIEyZqTqIMxl7u8TwL6IyoNI8CP9MxnrJOjZzUGUp04n-ioLY8x3sJORR91datKpoKoV",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJsa4IqeR53Q4Rj0yez_Dqrso",
#             "plus_code": {
#                 "compound_code": "975M+53 Cap Skirring, Senegal",
#                 "global_code": "7C45975M+53"
#             },
#             "rating": 4.1,
#             "reference": "ChIJsa4IqeR53Q4Rj0yez_Dqrso",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "Kabrousse Road, Cap Skirring"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 12.3675711,
#                     "lng": -16.729974
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.36878062989272,
#                         "lng": -16.72860422010727
#                     },
#                     "southwest": {
#                         "lat": 12.36608097010727,
#                         "lng": -16.73130387989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Paco touty lodge",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103584660202203348160\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwL8bAwt_-WvIgWJzKl42ey6AvEZL-gNTYVMzohrKyR9-bweQLInb0H__JZKm1vXfEGgQOo15ZgmWq9V5UeWUr-SkWUFms4ImfLFQ-LspQ_s8_24PdXyoqBkU-ckJedl0767lZ5ck6LZxy9qubWK4NQq3TStISZCLpE48cuKisAuPYCf",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJJYXyqdtx3Q4RWY7krXAwoSA",
#             "plus_code": {
#                 "compound_code": "979C+22 Cap Skirring, Senegal",
#                 "global_code": "7C45979C+22"
#             },
#             "rating": 4,
#             "reference": "ChIJJYXyqdtx3Q4RWY7krXAwoSA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Cap, Cap Skirring"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 12.3621167,
#                     "lng": -16.7281481
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.36342042989272,
#                         "lng": -16.72707472010728
#                     },
#                     "southwest": {
#                         "lat": 12.36072077010728,
#                         "lng": -16.72977437989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "La MARSU",
#             "photos": [
#                 {
#                     "height": 1800,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106067883836176448184\">Aris Danso</a>"
#                     ],
#                     "photo_reference": "ATtYBwLeTkfsVYgICm5KEsFK3JE7Of2hQ_PSN7IFVgzGhIjQlTdXgjrVlpSMcWYm3kMucfKQuY5TyQJymh0ve5Eq3L0Pt1-_2uocxMET6c9548aMhEvGxuRviUXAjmNK_vkjc0IWAbrMWF5QwPUsVrp1PZoFWAeNZomdHt4nhka-ZYJmtyuS",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJh7jhvlZ33Q4RT4tmSohyg-g",
#             "plus_code": {
#                 "compound_code": "976C+RP Cap Skirring, Senegal",
#                 "global_code": "7C45976C+RP"
#             },
#             "rating": 4.1,
#             "reference": "ChIJh7jhvlZ33Q4RT4tmSohyg-g",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 165,
#             "vicinity": "Cap Skirring"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 12.3510823,
#                     "lng": -16.7251983
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.35263042989272,
#                         "lng": -16.72398047010728
#                     },
#                     "southwest": {
#                         "lat": 12.34993077010728,
#                         "lng": -16.72668012989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "LES HIBISCUS - DOMAINE DE LA PALMERAIE \u039e\u03b5\u03bd\u03bf\u03b4\u03bf\u03c7\u03b5\u03af\u03bf",
#             "photos": [
#                 {
#                     "height": 1504,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100752946539950793003\">Ajay Dixit</a>"
#                     ],
#                     "photo_reference": "ATtYBwIOEBhVm_hcntl-wA_fTwMwPs9Us3qYW9n1f5gjjnhHSv3s_CBQ4kFnGIHGoCdjllV0qXy2NRD2FcbnARCYs9x4sWcf5ObKJCyU-yt-N9M5bccYLxZJ-nJkLh7hs3HFe1Q54NlPFLNaTNvnShW_l3t7pB6fx5Fi_kw6Wmonbjkcf1sk",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJkXjOyvR53Q4RhFxMDm3sUcs",
#             "plus_code": {
#                 "compound_code": "972F+CW Kabrousse, Senegal",
#                 "global_code": "7C45972F+CW"
#             },
#             "rating": 4.2,
#             "reference": "ChIJkXjOyvR53Q4RhFxMDm3sUcs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 125,
#             "vicinity": "Cabrousse 1 - BP 35, Kabrousse"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 12.365523,
#                     "lng": -16.729409
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.36688062989272,
#                         "lng": -16.72801227010728
#                     },
#                     "southwest": {
#                         "lat": 12.36418097010728,
#                         "lng": -16.73071192989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "No Stress Campement",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115681233124734387471\">Isabel Hern\u00e1ndez Sandoica</a>"
#                     ],
#                     "photo_reference": "ATtYBwKuP3dh5-z8HXcdrIqsFZDfc22rRRcxNjvAwxz8MBosr6t9J6eFjN1Y8B_A2jl46Lrp6Fcxf302bhzYa5-I4ZvbHEBXwJC6aJjoopsglOvQgyiDi-3YFuuNc7EJJ6nI1Ii1XYcPMOvc51rKq1y3YP-PUJvkjiUc09HZFYksOAiTsYZi",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJtyI_h1N33Q4RdK4InDfFs2o",
#             "plus_code": {
#                 "compound_code": "978C+66 Cap Skirring, Senegal",
#                 "global_code": "7C45978C+66"
#             },
#             "rating": 4.1,
#             "reference": "ChIJtyI_h1N33Q4RdK4InDfFs2o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 125,
#             "vicinity": "Cap Skirring"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 12.3753468,
#                     "lng": -16.7315736
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.37679862989272,
#                         "lng": -16.73024732010728
#                     },
#                     "southwest": {
#                         "lat": 12.37409897010728,
#                         "lng": -16.73294697989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "au ptit bonheur",
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110467756989070810618\">jean michel Legros</a>"
#                     ],
#                     "photo_reference": "ATtYBwLG-j_uTnA3t81a5HhBbZi7mHw4bgc4IYurlnBEY5sSimT8JZCn843QUp2zQ_xWYO46sf20v_wxjlvOkMyHEkyhEmBsM1t2qNU6-ZxxYDclMZqhpfhwfhBTuZmTl5KkPcI-Ko9g1kvYyKj1sSGjy5BrwtMlveTqYiOclgYy5022Bpz7",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJDYuHja5w3Q4R3EeXhsDuECo",
#             "plus_code": {
#                 "compound_code": "97G9+49 Cap Skirring, Senegal",
#                 "global_code": "7C4597G9+49"
#             },
#             "rating": 3.5,
#             "reference": "ChIJDYuHja5w3Q4R3EeXhsDuECo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Cap Randoul\u00e8ne"
#         }
#     ],
#     "status": "OK"
# }
#    Latitude  Longitude            City Country Code  Max Temp  Humidity  \
# 0   33.3406    44.4009         baghdad           iq     73.40      38.0
# 1   16.2526   -61.2741  saint-francois           gp     75.20      88.0
# 2   27.2574    33.8129        hurghada           eg     77.00      16.0
# 3  -23.8650    35.3833       inhambane           mz     71.98      77.0
# 4   23.9167  -106.9000         la cruz           mx     70.00      81.0
# 5    4.9333   -52.3333         cayenne           gf     78.01     100.0
# 6    5.1552   -52.6478          kourou           gf     78.01     100.0
# 7   24.6877    46.7219          riyadh           sa     73.40      27.0
# 8   12.4850   -16.5469        oussouye           sn     73.40      83.0
#
#    Cloudiness  Wind Speed          Date                      Hotel Name
# 0         0.0        6.91  1.619749e+09                  Babylon Rotana
# 1         0.0        2.30  1.619750e+09     LA CREOLE BEACH HOTEL & SPA
# 2         0.0        6.91  1.619750e+09
# 3         0.0        5.53  1.619749e+09          Sentidos Beach Retreat
# 4         0.0        1.01  1.619750e+09                  Toninas México
# 5         0.0        4.29  1.619749e+09  Mercure Cayenne Royal Amazonia
# 6         0.0        3.22  1.619750e+09  Mercure Cayenne Royal Amazonia
# 7         0.0        3.44  1.619749e+09            Vittori Palace Hotel
# 8         0.0        4.61  1.619750e+09             Le Papayer EcoLodge

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-464b2b3e63ad> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# <ipython-input-9-464b2b3e63ad> in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# KeyError: 'Country'

# %%
hotel_options = hotel_df["Hotel Name"].tolist()

# Add marker layer ontop of heat map
marker_locations = hotel_df[['Latitude', 'Longitude']]

# Create a marker_layer using the poverty list to fill the info box
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations,
    info_box_content=[f"Hotel Locations: {hotel}" for hotel in hotel_options])
fig.add_layer(markers)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
